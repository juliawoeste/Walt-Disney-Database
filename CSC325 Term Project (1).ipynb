# %% [markdown]
# <p>Humna Hanif, Julia Woeste
#
# </p>
# <p>
#     Professor ElKharboutly
# </p>
# <p>
#     CSC325-01
# </p>
# <p>
#    December 7th, 2022
# </p>

# %% [markdown]
# ## Milestone 1
# # Walt Disney Character Dataset
# <u> Dataset Information </u>
# <ol>
#     <li>Dataset Source: <a href = " https://www.kaggle.com/datasets/maricinnamon/walt-disney-character-dataset?select=disney_movies_total_gross.csv" target = "_blank">Walt Disney Character Dataset</a></li>
#     <li>Description of Dataset: This dataset included information on Walt Disney Characters. Many information about each character are given which include movie title, release date, total gross, genre, songs, heroes, villains, ratings, and so much more.</li>
#     <li>Attribute Description:</li>
#
#    </ol>
#            <p>
#                Name: Movie Title (VARCHAR(100))
#            </p>
#     <p>
#                Release Date: Date of Release (YYYY-MM-DD)
#     </p>
#     <p>
#                Total Gross: Total Earnings (INT(100,000,000,000))
#     </p>
#     <p>
#                Song: Song in Movie (VARCHAR(100))
#     </p>
#     <p>
#                Genre: Type of Movie (VARCHAR(100))
#     </p>
#     <p>
#                Character Type: Hero or Villain (VARCHAR(10))
#     </p>
#     <p>
#                Character Name: Name of Character (VARCHAR(100))
#     </p>
#     <p>
#                Rating: MPAA Rating (VARCHAR(15))
#     </p>

# %% [markdown]
# Tables:

# %% [markdown]
# Movies Table
#
# ![Screen%20Shot%202022-10-23%20at%2011.32.13%20AM.png](attachment:Screen%20Shot%202022-10-23%20at%2011.32.13%20AM.png)

# %% [markdown]
# Characters Table
#
# ![Screen%20Shot%202022-10-23%20at%2011.34.42%20AM.png](attachment:Screen%20Shot%202022-10-23%20at%2011.34.42%20AM.png)

# %% [markdown]
# Genre Table
#
# ![Screen%20Shot%202022-10-23%20at%2011.35.36%20AM.png](attachment:Screen%20Shot%202022-10-23%20at%2011.35.36%20AM.png)

# %% [markdown]
# Rating Table
# ![PNG%20image.jpeg](attachment:PNG%20image.jpeg)

# %% [markdown]
# <p>Movie-Character Table</p>
#
# ![Screen%20Shot%202022-10-25%20at%201.31.31%20PM.png](attachment:Screen%20Shot%202022-10-25%20at%201.31.31%20PM.png)

# %% [markdown]
# <p>4. Normalization</p>

# %% [markdown]
# First Normal Form:
# ![PNG%20image.jpeg](attachment:PNG%20image.jpeg)

# %% [markdown]
# Second and Third Normal Form:
# ![PNG%20image.jpeg](attachment:PNG%20image.jpeg)

# %% [markdown]
# <p>5. ER Diagram</p>

# %% [markdown]
# ![Screen%20Shot%202022-10-25%20at%2012.51.29%20PM.png](attachment:Screen%20Shot%202022-10-25%20at%2012.51.29%20PM.png)

# %% [markdown]
# <p>6. RM Diagram</p>

# %% [markdown]
# ![Screen%20Shot%202022-10-25%20at%201.03.21%20PM.png](attachment:Screen%20Shot%202022-10-25%20at%201.03.21%20PM.png)

# %% [markdown]
# <p>7. Dashboard</p>

# %% [markdown]
# <p>Pie Chart</p>

# %% [markdown]
# ![Pie%20Chart.png](attachment:Pie%20Chart.png)

# %% [markdown]
# <p>Bar Graph</p>

# %% [markdown]
# ![Bar%20Graph.jpeg](attachment:Bar%20Graph.jpeg)

# %% [markdown]
# Donut Graph
# ![PNG%20image.jpeg](attachment:PNG%20image.jpeg)

# %% [markdown]
# Change the amount, 16 and 16

# %% [markdown]
# <p>Line Graph</p>
#
# ![Line%20Graph.png](attachment:Line%20Graph.png)

# %% [markdown]
# Pie Chart
# ![PNG%20image.jpeg](attachment:PNG%20image.jpeg)

# %% [markdown]
# [Milestone 2](http://localhost:8888/notebooks/CSC%20Term%20Project/CSC325%20Milestone%202.ipynb)

# %% [markdown]
# [Milestone 3](http://localhost:8888/notebooks/CSC%20Term%20Project/Milestone%203.ipynb)
